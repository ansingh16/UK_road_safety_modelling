# %% [markdown]
# ## UK Accident Data
#
# The dataset contains detailed records of road traffic accidents across the UK, including:
# - Collision details (time, location, weather, road type, speed limit, lighting)
# - Vehicles involved (type, manoeuvre, movement, load)
# - Casualties (age, gender, role, severity)
#
# The definition of these parameters are given in :[Instructions for the Completion of Road Accident Reports](https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/995424/stats20-2005.pdf)

# %%
# !ls ../data/
# Out:
# dft-road-casualty-statistics-casualty-2023.csv
# dft-road-casualty-statistics-collision-2023.csv
# dft-road-casualty-statistics-vehicle-2023.csv

# %%
# load libraries
import pandas as pd
import numpy as np
import plotly.express as px
import pathlib

# set working directory
data_dir = pathlib.Path('../data/')

# %% [markdown]
# ### Loading road casuality data

# %%
# collision statistics
df_casualties = (pd.read_csv(
    data_dir/'dft-road-casualty-statistics-collision-2023.csv',
    low_memory=False)
    .set_index('accident_index'))
df_casualties.head()
# Out:
#                 accident_year accident_reference  location_easting_osgr  \
# accident_index
# 2023010419171            2023          010419171               525060.0
# 2023010419183            2023          010419183               535463.0
# 2023010419189            2023          010419189               508702.0
# 2023010419191            2023          010419191               520341.0
# 2023010419192            2023          010419192               527255.0
#
#                 location_northing_osgr  longitude   latitude  police_force  \
# accident_index
# 2023010419171                 170416.0  -0.202878  51.418974             1
# 2023010419183                 198745.0  -0.042464  51.671155             1
# 2023010419189                 177696.0  -0.435789  51.487777             1
# 2023010419191                 190175.0  -0.263972  51.597575             1
# 2023010419192                 176963.0  -0.168976  51.477324             1
#
#                 accident_severity  number_of_vehicles  number_of_casualties  \
# accident_index
# 2023010419171                   3                   1                     1
# 2023010419183                   3                   3                     2
# 2023010419189                   3                   2                     1
# 2023010419191                   3                   2                     1
# 2023010419192                   3                   2                     1
#
#                 ... light_conditions  weather_conditions  \
# accident_index  ...
# 2023010419171   ...                4                   8
# 2023010419183   ...                4                   1
# 2023010419189   ...                4                   1
# 2023010419191   ...                4                   9
# 2023010419192   ...                4                   1
#
#                road_surface_conditions  special_conditions_at_site  \
# accident_index
# 2023010419171                        2                           0
# 2023010419183                        1                           0
# 2023010419189                        1                           0
# 2023010419191                        1                           0
# 2023010419192                        1                           0
#
#                carriageway_hazards urban_or_rural_area  \
# accident_index
# 2023010419171                    0                   1
# 2023010419183                    0                   1
# 2023010419189                    0                   1
# 2023010419191                    0                   1
# 2023010419192                    0                   1
#
#                 did_police_officer_attend_scene_of_accident  trunk_road_flag  \
# accident_index
# 2023010419171                                             1                2
# 2023010419183                                             1                2
# 2023010419189                                             1                2
# 2023010419191                                             1                2
# 2023010419192                                             1                2
#
#                 lsoa_of_accident_location  enhanced_severity_collision
# accident_index
# 2023010419171                   E01003383                           -1
# 2023010419183                   E01001547                           -1
# 2023010419189                   E01002448                           -1
# 2023010419191                   E01000129                           -1
# 2023010419192                   E01004583                           -1
#
# [5 rows x 36 columns]

# %%
# get columns
df_casualties.columns
# Out:
# Index(['accident_year', 'accident_reference', 'location_easting_osgr',
#        'location_northing_osgr', 'longitude', 'latitude', 'police_force',
#        'accident_severity', 'number_of_vehicles', 'number_of_casualties',
#        'date', 'day_of_week', 'time', 'local_authority_district',
#        'local_authority_ons_district', 'local_authority_highway',
#        'first_road_class', 'first_road_number', 'road_type', 'speed_limit',
#        'junction_detail', 'junction_control', 'second_road_class',
#        'second_road_number', 'pedestrian_crossing_human_control',
#        'pedestrian_crossing_physical_facilities', 'light_conditions',
#        'weather_conditions', 'road_surface_conditions',
#        'special_conditions_at_site', 'carriageway_hazards',
#        'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident',
#        'trunk_road_flag', 'lsoa_of_accident_location',
#        'enhanced_severity_collision'],
#       dtype='object')

# %%
fig = px.scatter_map(
    df_casualties,  
    lat= 'latitude',
    lon= 'longitude',
    width=800, 
    height=600,
    color= 'accident_severity',
    hover_data=["accident_severity"] # accident severity
   
)

fig.update_layout(
    coloraxis_colorbar= {'title': 'Accident Severity'},
    mapbox_style="open-street-map")
fig.show()

# %% [markdown]
# Check for completeness of the data

# %%
df_casualties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 104258 entries, 2023010419171 to 2023991462793
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   accident_year                                104258 non-null  int64
#  1   accident_reference                           104258 non-null  object
#  2   location_easting_osgr                        104246 non-null  float64
#  3   location_northing_osgr                       104246 non-null  float64
#  4   longitude                                    104246 non-null  float64
#  5   latitude                                     104246 non-null  float64
#  6   police_force                                 104258 non-null  int64
#  7   accident_severity                            104258 non-null  int64
#  8   number_of_vehicles                           104258 non-null  int64
#  9   number_of_casualties                         104258 non-null  int64
#  10  date                                         104258 non-null  object
#  11  day_of_week                                  104258 non-null  int64
#  12  time                                         104258 non-null  object
#  13  local_authority_district                     104258 non-null  int64
#  14  local_authority_ons_district                 104258 non-null  object
#  15  local_authority_highway                      104258 non-null  object
#  16  first_road_class                             104258 non-null  int64
#  17  first_road_number                            104258 non-null  int64
#  18  road_type                                    104258 non-null  int64
#  19  speed_limit                                  104258 non-null  int64
#  20  junction_detail                              104258 non-null  int64
#  21  junction_control                             104258 non-null  int64
#  22  second_road_class                            104258 non-null  int64
#  23  second_road_number                           104258 non-null  int64
#  24  pedestrian_crossing_human_control            104258 non-null  int64
#  25  pedestrian_crossing_physical_facilities      104258 non-null  int64
#  26  light_conditions                             104258 non-null  int64
#  27  weather_conditions                           104258 non-null  int64
#  28  road_surface_conditions                      104258 non-null  int64
#  29  special_conditions_at_site                   104258 non-null  int64
#  30  carriageway_hazards                          104258 non-null  int64
#  31  urban_or_rural_area                          104258 non-null  int64
#  32  did_police_officer_attend_scene_of_accident  104258 non-null  int64
#  33  trunk_road_flag                              104258 non-null  int64
#  34  lsoa_of_accident_location                    104258 non-null  object
#  35  enhanced_severity_collision                  104258 non-null  int64
# dtypes: float64(4), int64(26), object(6)
# memory usage: 29.4+ MB
